# %%
import pandas as pd

# 데이터 파일 불러오기
data = pd.read_csv('FnB.csv')
data.head()
# Out:
#      title            contentsid type_value type_label  \
# 0    비자블라썸  CNTS_200000000007261         c4        음식점
# 1  유심이감성찜닭  CNTS_200000000009123         c4        음식점
# 2    솜반내풍경  CNTS_000000000022942         c4        음식점
# 3     잔디가미  CNTS_000000000022454         c4        음식점
# 4    토투가커피  CNTS_200000000014702         c4        음식점
#
#                       address                roadaddress postcode  \
# 0  제주특별자치도 제주시 구좌읍 평대리 3210-4  제주특별자치도 제주시 구좌읍 비자림로 2244        -
# 1  제주특별자치도 제주시 추자면 영흥리 364-18     제주특별자치도 제주시 추자면 추자로 78      NaN
# 2     제주특별자치도 서귀포시 서홍동 1223-7        제주특별자치도 서귀포시 서홍로 60    63584
# 3      제주특별자치도 제주시 우도면 연평리 26  제주특별자치도 제주시 우도면 우도해안길 912      NaN
# 4  제주특별자치도 제주시 한림읍 귀덕리 3020-2    제주특별자치도 제주시 한림읍 귀덕9길 19      NaN
#
#           phoneno    latitude    longitude region1cd_value region1cd_label  \
# 0   010-4449-3885  33.5312449  126.8506911         region1             제주시
# 1   010-3512-9016  33.9567036  126.2969646         region3          섬 속의 섬
# ...

# %%
null_counts = data.isnull().sum()
null_counts
# Out:
# title                 0
# contentsid            0
# type_value            0
# type_label            0
# address               0
# roadaddress           0
# postcode           1444
# phoneno               1
# latitude              0
# longitude             0
# region1cd_value       0
# region1cd_label       0
# region2cd_value       0
# region2cd_label       0
# photoid               0
# imgpath               0
# thumbnailpath         0
# introduction          0
# alltags              49
# tag                  49
# dtype: int64
