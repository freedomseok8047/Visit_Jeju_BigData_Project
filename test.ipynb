# %%
import pandas as pd

# 데이터 파일 불러오기
data = pd.read_csv('주요관광지점_입장객_2020-2022.csv')

# '총계' 열을 기준으로 내림차순 정렬
sorted_data = data.sort_values(by='총계', ascending=False)

# 정렬된 데이터를 출력
print(sorted_data)
# Out:
#          시도    군구          관광지       총계
# 0   제주특별자치도  서귀포시        천지연폭포  2507172
# 1   제주특별자치도   제주시      한라산국립공원  2155639
# 2   제주특별자치도   제주시          비자림  2094672
# 3   제주특별자치도  서귀포시  중문대포해안주상절리대  2050526
# 4   제주특별자치도  서귀포시        성산일출봉  1782849
# 5   제주특별자치도  서귀포시         정방폭포  1640313
# 6   제주특별자치도   제주시      절물자연휴양림  1596805
# 7   제주특별자치도  서귀포시   한화아쿠아플라넷제주  1549976
# 8   제주특별자치도  서귀포시     마라해양도립공원  1492207
# 9   제주특별자치도  서귀포시        카멜리아힐  1368326
# 10  제주특별자치도  서귀포시          산방산  1187698
# 11  제주특별자치도   제주시       만장굴관광지  1138013
# 12  제주특별자치도  서귀포시        천제연폭포  1024594
# 13  제주특별자치도  서귀포시     서귀포자연휴양림   443662
# 14  제주특별자치도   제주시      국립제주박물관   432192
# 15  제주특별자치도  서귀포시     박물관은살아있다   423773
# 16  제주특별자치도   제주시      제주돌문화공원   360165
# 17  제주특별자치도   제주시     민속자연사박물관   275896
# 18  제주특별자치도   제주시       항몽 유적지   252760
# 19  제주특별자치도  서귀포시       이중섭미술관   251805
# 20  제주특별자치도  서귀포시         일출랜드   248232
# 21  제주특별자치도   제주시      제주현대미술관   245543
# 22  제주특별자치도  서귀포시        퍼시픽랜드   233601
# 23  제주특별자치도  서귀포시    서귀포도립해양공원   228057
# 24  제주특별자치도   제주시       해녀 박물관   198812
# 25  제주특별자치도   제주시      제주항일기념관   181552
# 26  제주특별자치도   제주시  제주도립 김창열미술관   162900
# 27  제주특별자치도   제주시       제주목관아지   152776
# 28  제주특별자치도  서귀포시        감귤박물관   150938
# 29  제주특별자치도   제주시        도립미술관   126848
# 30  제주특별자치도  서귀포시        제주추사관    82310
# 31  제주특별자치도   제주시     제주별빛누리공원    60229
# 32  제주특별자치도  서귀포시        서복전시관    53548
# 33  제주특별자치도   제주시      삼양선사유적지    48284
# 34  제주특별자치도  서귀포시        기당미술관    36058
# 35  제주특별자치도  서귀포시     제주국제평화센터    30890

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정
fm._get_fontconfig_fonts()
font_location = '/Users/user/Library/Fonts/D2Coding-Ver1.3.2-20180524-all.ttc'
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# 데이터 불러오기
data = pd.read_csv('주요관광지점 입장객 2022년.csv')

# '총계' 열을 기준으로 내림차순 정렬
sorted_data = data.sort_values(by='총계', ascending=False)

# 막대 그래프 그리기
plt.figure(figsize=(10, 8))  # 그래프 크기 설정
plt.bar(sorted_data['관광지'], sorted_data['총계'])  # 막대 그래프 생성
plt.xlabel('관광지')  # x축 라벨
plt.ylabel('총계')  # y축 라벨
plt.title('2022년 관광지별 입장객 수')  # 그래프 제목
plt.xticks(rotation=90)  # x축 라벨 회전
plt.show()  # 그래프 출력
