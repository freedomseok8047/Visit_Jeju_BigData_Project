# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import font_manager as fm, rc
# Path to the uploaded font file
font_path = 'BMYEONSUNG_otf.otf'

# Add the font to Matplotlib's font manager
fm.fontManager.addfont(font_path)

# Set the font as the default for all text in Matplotlib
font_prop = fm.FontProperties(fname=font_path)
rc('font', family=font_prop.get_name())

data = pd.read_csv('지역별_소비타입_연령_성별.csv')
data
# Out:
#      sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 0     제주도     제주시        읍면         유흥     제주도민    60대이상      여       201812
# 1     제주도     제주시        읍면         유흥     제주도민    60대이상      남       201812
# 2     제주도     제주시        읍면         유흥     제주도민      50대      여       201812
# 3     제주도     제주시        읍면         유흥     제주도민      50대      남       201812
# 4     제주도     제주시        읍면         유흥     제주도민      40대      여       201812
# ...   ...     ...       ...        ...      ...      ...    ...          ...
# 8014  제주도    서귀포시        도심         교통   내국인관광객      30대      남       201801
# 8015  제주도    서귀포시        도심         교통   내국인관광객    20대미만      여       201801
# 8016  제주도    서귀포시        도심         교통   내국인관광객    20대미만      남       201801
# 8017  제주도    서귀포시        도심         교통   내국인관광객      20대      여       201801
# 8018  제주도    서귀포시        도심         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost
# 0            23        29   4240100
# 1           114       190  27414000
# 2            52        71   6848000
# 3           259       458  91468500
# 4            77        99  10021600
# ...         ...       ...       ...
# 8014       1442      1691  70364681
# 8015          6         6    177975
# 8016          1         1     20000
# 8017        602       634  19857600
# 8018        692       756  29157095
#
# [8019 rows x 11 columns]

# %%
# 'userType' 필드가 '제주도민'인 행을 삭제
data = data[data['userType'] != '제주도민']

# 결과 확인
data
# Out:
#      sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 11    제주도     제주시        읍면         유흥   내국인관광객    60대이상      여       201812
# 12    제주도     제주시        읍면         유흥   내국인관광객    60대이상      남       201812
# 13    제주도     제주시        읍면         유흥   내국인관광객      50대      여       201812
# 14    제주도     제주시        읍면         유흥   내국인관광객      50대      남       201812
# 15    제주도     제주시        읍면         유흥   내국인관광객      40대      여       201812
# ...   ...     ...       ...        ...      ...      ...    ...          ...
# 8014  제주도    서귀포시        도심         교통   내국인관광객      30대      남       201801
# 8015  제주도    서귀포시        도심         교통   내국인관광객    20대미만      여       201801
# 8016  제주도    서귀포시        도심         교통   내국인관광객    20대미만      남       201801
# 8017  제주도    서귀포시        도심         교통   내국인관광객      20대      여       201801
# 8018  제주도    서귀포시        도심         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost
# 11           16        21   4474000
# 12           45        59   8459100
# 13           38        47   4403500
# 14          136       174  23659532
# 15           60        74   5511100
# ...         ...       ...       ...
# 8014       1442      1691  70364681
# 8015          6         6    177975
# 8016          1         1     20000
# 8017        602       634  19857600
# 8018        692       756  29157095
#
# [4002 rows x 11 columns]

# %%
# data = data.drop(["sido"], axis=1, inplace=False)
data
# Out:
#      sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 11    제주도     제주시        읍면         유흥   내국인관광객    60대이상      여       201812
# 12    제주도     제주시        읍면         유흥   내국인관광객    60대이상      남       201812
# 13    제주도     제주시        읍면         유흥   내국인관광객      50대      여       201812
# 14    제주도     제주시        읍면         유흥   내국인관광객      50대      남       201812
# 15    제주도     제주시        읍면         유흥   내국인관광객      40대      여       201812
# ...   ...     ...       ...        ...      ...      ...    ...          ...
# 8014  제주도    서귀포시        도심         교통   내국인관광객      30대      남       201801
# 8015  제주도    서귀포시        도심         교통   내국인관광객    20대미만      여       201801
# 8016  제주도    서귀포시        도심         교통   내국인관광객    20대미만      남       201801
# 8017  제주도    서귀포시        도심         교통   내국인관광객      20대      여       201801
# 8018  제주도    서귀포시        도심         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost
# 11           16        21   4474000
# 12           45        59   8459100
# 13           38        47   4403500
# 14          136       174  23659532
# 15           60        74   5511100
# ...         ...       ...       ...
# 8014       1442      1691  70364681
# 8015          6         6    177975
# 8016          1         1     20000
# 8017        602       634  19857600
# 8018        692       756  29157095
#
# [4002 rows x 11 columns]

# %%
# 'sigungu'와 'cityGubun' 열을 합치는 코드
data['combined_region'] = data['sigungu'] + ' ' + data['cityGubun']

# 결과 확인
# data[['sigungu', 'cityGubun', 'combined_region']].head()
data
# Out:
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_7568/39243625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['combined_region'] = data['sigungu'] + ' ' + data['cityGubun']
#      sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 11    제주도     제주시        읍면         유흥   내국인관광객    60대이상      여       201812
# 12    제주도     제주시        읍면         유흥   내국인관광객    60대이상      남       201812
# 13    제주도     제주시        읍면         유흥   내국인관광객      50대      여       201812
# 14    제주도     제주시        읍면         유흥   내국인관광객      50대      남       201812
# 15    제주도     제주시        읍면         유흥   내국인관광객      40대      여       201812
# ...   ...     ...       ...        ...      ...      ...    ...          ...
# 8014  제주도    서귀포시        도심         교통   내국인관광객      30대      남       201801
# 8015  제주도    서귀포시        도심         교통   내국인관광객    20대미만      여       201801
# 8016  제주도    서귀포시        도심         교통   내국인관광객    20대미만      남       201801
# 8017  제주도    서귀포시        도심         교통   내국인관광객      20대      여       201801
# 8018  제주도    서귀포시        도심         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost combined_region
# 11           16        21   4474000          제주시 읍면
# 12           45        59   8459100          제주시 읍면
# 13           38        47   4403500          제주시 읍면
# 14          136       174  23659532          제주시 읍면
# 15           60        74   5511100          제주시 읍면
# ...         ...       ...       ...             ...
# 8014       1442      1691  70364681         서귀포시 도심
# 8015          6         6    177975         서귀포시 도심
# 8016          1         1     20000         서귀포시 도심
# 8017        602       634  19857600         서귀포시 도심
# 8018        692       756  29157095         서귀포시 도심
#
# [4002 rows x 12 columns]

# %%
data = data.drop(["sigungu"], axis=1, inplace=False)
data = data.drop(["cityGubun"], axis=1, inplace=False)
data
# Out:
#      sido marketType userType ageGroup gender  dtYearMonth  userCount  \
# 11    제주도         유흥   내국인관광객    60대이상      여       201812         16
# 12    제주도         유흥   내국인관광객    60대이상      남       201812         45
# 13    제주도         유흥   내국인관광객      50대      여       201812         38
# 14    제주도         유흥   내국인관광객      50대      남       201812        136
# 15    제주도         유흥   내국인관광객      40대      여       201812         60
# ...   ...        ...      ...      ...    ...          ...        ...
# 8014  제주도         교통   내국인관광객      30대      남       201801       1442
# 8015  제주도         교통   내국인관광객    20대미만      여       201801          6
# 8016  제주도         교통   내국인관광객    20대미만      남       201801          1
# 8017  제주도         교통   내국인관광객      20대      여       201801        602
# 8018  제주도         교통   내국인관광객      20대      남       201801        692
#
#       useCount   useCost combined_region
# 11          21   4474000          제주시 읍면
# 12          59   8459100          제주시 읍면
# 13          47   4403500          제주시 읍면
# 14         174  23659532          제주시 읍면
# 15          74   5511100          제주시 읍면
# ...        ...       ...             ...
# 8014      1691  70364681         서귀포시 도심
# 8015         6    177975         서귀포시 도심
# 8016         1     20000         서귀포시 도심
# 8017       634  19857600         서귀포시 도심
# 8018       756  29157095         서귀포시 도심
#
# [4002 rows x 10 columns]

# %%
# 'combined_region' 열을 추출하고 데이터 프레임에서 제거
combined_region_column = data.pop('combined_region')

# 'combined_region' 열을 첫 번째 열로 삽입
data.insert(0, 'combined_region', combined_region_column)

# 결과 확인
data.head()
# Out:
#    combined_region sido marketType userType ageGroup gender  dtYearMonth  \
# 11          제주시 읍면  제주도         유흥   내국인관광객    60대이상      여       201812
# 12          제주시 읍면  제주도         유흥   내국인관광객    60대이상      남       201812
# 13          제주시 읍면  제주도         유흥   내국인관광객      50대      여       201812
# 14          제주시 읍면  제주도         유흥   내국인관광객      50대      남       201812
# 15          제주시 읍면  제주도         유흥   내국인관광객      40대      여       201812
#
#     userCount  useCount   useCost
# 11         16        21   4474000
# 12         45        59   8459100
# 13         38        47   4403500
# 14        136       174  23659532
# 15         60        74   5511100

# %%
# 현재 작업 디렉토리에 CSV 파일로 저장
csv_file_name = '카드소비패턴_수정.csv'

# 데이터 프레임을 CSV 파일로 저장
data.to_csv(csv_file_name, index=False)

# %%
data = pd.read_csv('카드소비패턴_수정.csv')
data
# Out:
#      combined_region sido marketType userType ageGroup gender  dtYearMonth  \
# 0             제주시 읍면  제주도         유흥   내국인관광객    60대이상      여       201812
# 1             제주시 읍면  제주도         유흥   내국인관광객    60대이상      남       201812
# 2             제주시 읍면  제주도         유흥   내국인관광객      50대      여       201812
# 3             제주시 읍면  제주도         유흥   내국인관광객      50대      남       201812
# 4             제주시 읍면  제주도         유흥   내국인관광객      40대      여       201812
# ...              ...  ...        ...      ...      ...    ...          ...
# 3997         서귀포시 도심  제주도         교통   내국인관광객      30대      남       201801
# 3998         서귀포시 도심  제주도         교통   내국인관광객    20대미만      여       201801
# 3999         서귀포시 도심  제주도         교통   내국인관광객    20대미만      남       201801
# 4000         서귀포시 도심  제주도         교통   내국인관광객      20대      여       201801
# 4001         서귀포시 도심  제주도         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost
# 0            16        21   4474000
# 1            45        59   8459100
# 2            38        47   4403500
# 3           136       174  23659532
# 4            60        74   5511100
# ...         ...       ...       ...
# 3997       1442      1691  70364681
# 3998          6         6    177975
# 3999          1         1     20000
# 4000        602       634  19857600
# 4001        692       756  29157095
#
# [4002 rows x 10 columns]

# %%
import matplotlib

# Check the unique values in 'combined_region'
unique_regions = data['combined_region'].unique()
unique_regions
# Out:
# array(['제주시 읍면', '제주시 도심', '서귀포시 읍면', '서귀포시 도심'], dtype=object)

# %%
# 각 컬럼의 카테고리 별로 'userCount', 'useCount', 'useCost'의 합계 계산
grouped_data = data.groupby(['combined_region', 'marketType', 'userType', 'ageGroup', 'gender', 'dtYearMonth'])\
                   .agg({'userCount': 'sum', 'useCount': 'sum', 'useCost': 'sum'}).reset_index()

# 결과 데이터 프레임 확인
grouped_data
# Out:
#      combined_region marketType userType ageGroup gender  dtYearMonth  \
# 0            서귀포시 도심         교통   내국인관광객      20대      남       201801
# 1            서귀포시 도심         교통   내국인관광객      20대      남       201802
# 2            서귀포시 도심         교통   내국인관광객      20대      남       201803
# 3            서귀포시 도심         교통   내국인관광객      20대      남       201804
# 4            서귀포시 도심         교통   내국인관광객      20대      남       201805
# ...              ...        ...      ...      ...    ...          ...
# 3997          제주시 읍면         유흥   내국인관광객    60대이상      여       201808
# 3998          제주시 읍면         유흥   내국인관광객    60대이상      여       201809
# 3999          제주시 읍면         유흥   내국인관광객    60대이상      여       201810
# 4000          제주시 읍면         유흥   내국인관광객    60대이상      여       201811
# 4001          제주시 읍면         유흥   내국인관광객    60대이상      여       201812
#
#       userCount  useCount   useCost
# 0           692       756  29157095
# 1           722       758  25676338
# 2           752       806  26269055
# 3           679       751  23895294
# 4           637       702  24133996
# ...         ...       ...       ...
# 3997         20        32   3580500
# 3998         25        33   2303300
# 3999         25        38   4963640
# 4000         11        19   2279500
# 4001         16        21   4474000
#
# [4002 rows x 9 columns]

# %%
# 현재 작업 디렉토리에 CSV 파일로 저장
csv_file_name = '카드소비패턴_수정2.csv'

# 데이터 프레임을 CSV 파일로 저장
data.to_csv(csv_file_name, index=False)

# %%
# '20대 미만'을 가장 앞으로 오게 재배열
data['ageGroup'] = pd.Categorical(data['ageGroup'], categories=['20대 미만', '20대', '30대', '40대', '50대', '60대 이상'], ordered=True)

# Z-Score 정규화를 위한 컬럼 선택
columns_to_normalize = ['userCount', 'useCount', 'useCost']

# Z-Score 정규화 적용
data[columns_to_normalize] = data[columns_to_normalize].apply(zscore)

# 모든 값을 양수화
data[columns_to_normalize] = data[columns_to_normalize] + 1

# 정규화된 데이터로 막대그래프 그리기를 위한 데이터 melt
data_melted = pd.melt(data, id_vars=['combined_region', 'marketType', 'userType', 'ageGroup', 'gender', 'dtYearMonth'], 
                      value_vars=columns_to_normalize, var_name='Metric', value_name='Normalized Value')

# 카테고리별로 막대그래프 그리기
categories = ['combined_region', 'marketType', 'ageGroup', 'gender', 'dtYearMonth']

plt.figure(figsize=(15, 20))
for i, category in enumerate(categories, 1):
    plt.subplot(3, 2, i)
    sns.barplot(data=data_melted, x='Metric', y='Normalized Value', hue=category)
    plt.title(f'Normalized Metrics by {category}')
    plt.xticks(rotation=45)
    plt.tight_layout()

# 모든 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/user/Visit_Jeju_BigData_Project/카드소비패턴.ipynb Cell 12 line 8
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> columns_to_normalize = ['userCount', 'useCount', 'useCost']
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> # Z-Score 정규화 적용
# ----> <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> data[columns_to_normalize] = data[columns_to_normalize].apply(zscore)
#      <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a> # 모든 값을 양수화
#      <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> data[columns_to_normalize] = data[columns_to_normalize] + 1
#
# NameError: name 'zscore' is not defined

# %%
# 그래프 그리기를 위한 서브플롯 설정
plt.figure(figsize=(18, 12))
plt.subplots_adjust(hspace=0.4)

# 지역별 userCount 그래프
plt.subplot(2, 3, 1)
sns.barplot(data=data, x='combined_region', y='userCount')
plt.title('User Count by Combined Region')
plt.xticks(rotation=45)
plt.xlabel('Combined Region')
plt.ylabel('User Count')

# 연령별 userCount 그래프
plt.subplot(2, 3, 2)
sns.barplot(data=data, x='ageGroup', y='userCount')
plt.title('User Count by Age Group')
plt.xticks(rotation=45)
plt.xlabel('Age Group')
plt.ylabel('User Count')

# 시장 유형별 userCount 그래프
plt.subplot(2, 3, 3)
sns.barplot(data=data, x='marketType', y='userCount')
plt.title('User Count by Market Type')
plt.xticks(rotation=45)
plt.xlabel('Market Type')
plt.ylabel('User Count')

# 성별 userCount 그래프
plt.subplot(2, 3, 4)
sns.barplot(data=data, x='gender', y='userCount')
plt.title('User Count by Gender')
plt.xlabel('Gender')
plt.ylabel('User Count')

# 월별 userCount 그래프
plt.subplot(2, 3, 5)
sns.barplot(data=data, x='dtYearMonth', y='userCount')
plt.title('User Count by dtYearMonth')
plt.xlabel('dtYearMonth')
plt.ylabel('User Count')

# 모든 그래프 표시
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 51021 (\N{HANGUL SYLLABLE EUB}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49900 (\N{HANGUL SYLLABLE SIM}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 55141 (\N{HANGUL SYLLABLE HEUNG}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49689 (\N{HANGUL SYLLABLE SUG}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 54609 (\N{HANGUL SYLLABLE PING}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 51256 (\N{HANGUL SYLLABLE JYEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   plt.tight_layout()
# /var/folders/pf/26dznxks2c72mq_6mvqz7y6h0000gn/T/ipykernel_12515/2834694362.py:44: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51021 (\N{HANGUL SYLLABLE EUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49900 (\N{HANGUL SYLLABLE SIM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 55141 (\N{HANGUL SYLLABLE HEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49689 (\N{HANGUL SYLLABLE SUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49660 (\N{HANGUL SYLLABLE SYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54609 (\N{HANGUL SYLLABLE PING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51256 (\N{HANGUL SYLLABLE JYEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/user/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
