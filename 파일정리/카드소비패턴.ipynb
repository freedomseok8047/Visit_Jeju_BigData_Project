# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import font_manager as fm, rc
# Path to the uploaded font file
font_path = 'BMYEONSUNG_otf.otf'

# Add the font to Matplotlib's font manager
fm.fontManager.addfont(font_path)

# Set the font as the default for all text in Matplotlib
font_prop = fm.FontProperties(fname=font_path)
rc('font', family=font_prop.get_name())

data = pd.read_csv('지역별_소비타입_연령_성별.csv')
data.head()
# Out:
#   sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 0  제주도     제주시        읍면         유흥     제주도민    60대이상      여       201812
# 1  제주도     제주시        읍면         유흥     제주도민    60대이상      남       201812
# 2  제주도     제주시        읍면         유흥     제주도민      50대      여       201812
# 3  제주도     제주시        읍면         유흥     제주도민      50대      남       201812
# 4  제주도     제주시        읍면         유흥     제주도민      40대      여       201812
#
#    userCount  useCount   useCost
# 0         23        29   4240100
# 1        114       190  27414000
# 2         52        71   6848000
# 3        259       458  91468500
# 4         77        99  10021600

# %%
# 'userType' 필드가 '제주도민'인 행을 삭제
data = data[data['userType'] != '제주도민']
# 결과 확인
data.head()
# Out:
#    sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 11  제주도     제주시        읍면         유흥   내국인관광객    60대이상      여       201812
# 12  제주도     제주시        읍면         유흥   내국인관광객    60대이상      남       201812
# 13  제주도     제주시        읍면         유흥   내국인관광객      50대      여       201812
# 14  제주도     제주시        읍면         유흥   내국인관광객      50대      남       201812
# 15  제주도     제주시        읍면         유흥   내국인관광객      40대      여       201812
#
#     userCount  useCount   useCost
# 11         16        21   4474000
# 12         45        59   8459100
# 13         38        47   4403500
# 14        136       174  23659532
# 15         60        74   5511100

# %%
data = data.drop(["sido"], axis=1, inplace=False)
data.head()
# Out:
#    sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 11     제주시        읍면         유흥   내국인관광객    60대이상      여       201812
# 12     제주시        읍면         유흥   내국인관광객    60대이상      남       201812
# 13     제주시        읍면         유흥   내국인관광객      50대      여       201812
# 14     제주시        읍면         유흥   내국인관광객      50대      남       201812
# 15     제주시        읍면         유흥   내국인관광객      40대      여       201812
#
#     userCount  useCount   useCost
# 11         16        21   4474000
# 12         45        59   8459100
# 13         38        47   4403500
# 14        136       174  23659532
# 15         60        74   5511100

# %%
# 'sigungu'와 'cityGubun' 열을 합치는 코드
# data['combined_region'] = data['sigungu'] + ' ' + data['cityGubun']

# 결과 확인
# data[['sigungu', 'cityGubun', 'combined_region']].head()
data
# Out:
#      sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 11       제주시        읍면         유흥   내국인관광객    60대이상      여       201812
# 12       제주시        읍면         유흥   내국인관광객    60대이상      남       201812
# 13       제주시        읍면         유흥   내국인관광객      50대      여       201812
# 14       제주시        읍면         유흥   내국인관광객      50대      남       201812
# 15       제주시        읍면         유흥   내국인관광객      40대      여       201812
# ...      ...       ...        ...      ...      ...    ...          ...
# 8014    서귀포시        도심         교통   내국인관광객      30대      남       201801
# 8015    서귀포시        도심         교통   내국인관광객    20대미만      여       201801
# 8016    서귀포시        도심         교통   내국인관광객    20대미만      남       201801
# 8017    서귀포시        도심         교통   내국인관광객      20대      여       201801
# 8018    서귀포시        도심         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost
# 11           16        21   4474000
# 12           45        59   8459100
# 13           38        47   4403500
# 14          136       174  23659532
# 15           60        74   5511100
# ...         ...       ...       ...
# 8014       1442      1691  70364681
# 8015          6         6    177975
# 8016          1         1     20000
# 8017        602       634  19857600
# 8018        692       756  29157095
#
# [4002 rows x 10 columns]

# %%
# data = data.drop(["sigungu"], axis=1, inplace=False)
# data = data.drop(["cityGubun"], axis=1, inplace=False)

data
# Out:
#      marketType userType ageGroup gender  dtYearMonth  userCount  useCount  \
# 11           유흥   내국인관광객    60대이상      여       201812         16        21
# 12           유흥   내국인관광객    60대이상      남       201812         45        59
# 13           유흥   내국인관광객      50대      여       201812         38        47
# 14           유흥   내국인관광객      50대      남       201812        136       174
# 15           유흥   내국인관광객      40대      여       201812         60        74
# ...         ...      ...      ...    ...          ...        ...       ...
# 8014         교통   내국인관광객      30대      남       201801       1442      1691
# 8015         교통   내국인관광객    20대미만      여       201801          6         6
# 8016         교통   내국인관광객    20대미만      남       201801          1         1
# 8017         교통   내국인관광객      20대      여       201801        602       634
# 8018         교통   내국인관광객      20대      남       201801        692       756
#
#        useCost
# 11     4474000
# 12     8459100
# 13     4403500
# 14    23659532
# 15     5511100
# ...        ...
# 8014  70364681
# 8015    177975
# 8016     20000
# 8017  19857600
# 8018  29157095
#
# [4002 rows x 8 columns]

# %%
# 'combined_region' 열을 추출하고 데이터 프레임에서 제거
combined_region_column = data.pop('combined_region')

# 'combined_region' 열을 첫 번째 열로 삽입
data.insert(0, 'combined_region', combined_region_column)

# 결과 확인
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'combined_region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/user/Visit_Jeju_BigData_Project/파일정리/카드소비패턴.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # 'combined_region' 열을 추출하고 데이터 프레임에서 제거
# ----> <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> combined_region_column = data.pop('combined_region')
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> # 'combined_region' 열을 첫 번째 열로 삽입
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> data.insert(0, 'combined_region', combined_region_column)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:5570, in DataFrame.pop(self, item)
#    5529 def pop(self, item: Hashable) -> Series:
#    5530     """
#    5531     Return item and drop from frame. Raise KeyError if not found.
#    5532
#    (...)
#    5568     3  monkey        NaN
#    5569     """
# -> 5570     return super().pop(item=item)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:901, in NDFrame.pop(self, item)
#     900 def pop(self, item: Hashable) -> Series | Any:
# --> 901     result = self[item]
#     902     del self[item]
#     904     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'combined_region'

# %%
# 현재 작업 디렉토리에 CSV 파일로 저장
csv_file_name = '카드소비패턴_수정.csv'

# 데이터 프레임을 CSV 파일로 저장
data.to_csv(csv_file_name, index=False)

# %%
data = pd.read_csv('카드소비패턴_수정.csv')
data.head()
# Out:
#   combined_region marketType userType ageGroup gender  dtYearMonth  userCount  \
# 0          제주시 읍면         유흥   내국인관광객    60대이상      여       201812         16
# 1          제주시 읍면         유흥   내국인관광객    60대이상      남       201812         45
# 2          제주시 읍면         유흥   내국인관광객      50대      여       201812         38
# 3          제주시 읍면         유흥   내국인관광객      50대      남       201812        136
# 4          제주시 읍면         유흥   내국인관광객      40대      여       201812         60
#
#    useCount   useCost
# 0        21   4474000
# 1        59   8459100
# 2        47   4403500
# 3       174  23659532
# 4        74   5511100

# %%
import matplotlib

# Check the unique values in 'combined_region'
unique_regions = data['combined_region'].unique()
unique_regions
# Out:
# array(['제주시 읍면', '제주시 도심', '서귀포시 읍면', '서귀포시 도심'], dtype=object)

# %%
# 각 컬럼의 카테고리 별로 'userCount', 'useCount', 'useCost'의 합계 계산
grouped_data = data.groupby(['combined_region', 'marketType', 'userType', 'ageGroup', 'gender', 'dtYearMonth'])\
                   .agg({'userCount': 'sum', 'useCount': 'sum', 'useCost': 'sum'}).reset_index()

# 결과 데이터 프레임 확인
grouped_data.head()
# Out:
#   combined_region marketType userType ageGroup gender  dtYearMonth  userCount  \
# 0         서귀포시 도심         교통   내국인관광객      20대      남       201801        692
# 1         서귀포시 도심         교통   내국인관광객      20대      남       201802        722
# 2         서귀포시 도심         교통   내국인관광객      20대      남       201803        752
# 3         서귀포시 도심         교통   내국인관광객      20대      남       201804        679
# 4         서귀포시 도심         교통   내국인관광객      20대      남       201805        637
#
#    useCount   useCost
# 0       756  29157095
# 1       758  25676338
# 2       806  26269055
# 3       751  23895294
# 4       702  24133996

# %%
# 현재 작업 디렉토리에 CSV 파일로 저장
csv_file_name = '카드소비패턴_수정2.csv'

# 데이터 프레임을 CSV 파일로 저장
data.to_csv(csv_file_name, index=False)

# %%
from scipy.stats import zscore
import seaborn as sns
import matplotlib.pyplot as plt

# '20대 미만'을 가장 앞으로 오게 재배열
data['ageGroup'] = pd.Categorical(data['ageGroup'],
categories=['20대 미만', '20대', '30대', '40대', '50대', '60대 이상'], ordered=True)

# Z-Score 정규화를 위한 컬럼 선택
columns_to_normalize = ['userCount', 'useCount', 'useCost']

# Z-Score 정규화 적용
data[columns_to_normalize] = data[columns_to_normalize].apply(zscore)

# 모든 값을 양수화
data[columns_to_normalize] = data[columns_to_normalize] + 1

# 정규화된 데이터로 막대그래프 그리기를 위한 데이터 melt
data_melted = pd.melt(data, id_vars=['combined_region', 'marketType', 'userType', 'ageGroup', 'gender', 'dtYearMonth'], 
                    value_vars=columns_to_normalize, var_name='Metric', value_name='Normalized Value')

# 카테고리별로 막대그래프 그리기
categories = ['combined_region', 'marketType', 'ageGroup', 'gender', 'dtYearMonth']

plt.figure(figsize=(15, 20))
for i, category in enumerate(categories, 1):
    plt.subplot(3, 2, i)
    sns.barplot(data=data_melted, x='Metric', y='Normalized Value', hue=category)
    plt.title(f'Normalized Metrics by {category}')
    plt.xticks(rotation=45)
    plt.tight_layout()

# 모든 그래프 표시
plt.show()

# %%
# 그래프 그리기를 위한 서브플롯 설정
plt.figure(figsize=(18, 12))
plt.subplots_adjust(hspace=0.4)

# 지역별 userCount 그래프
plt.subplot(2, 3, 1)
sns.barplot(data=data, x='combined_region', y='userCount')
plt.title('User Count by Combined Region')
plt.xticks(rotation=45)
plt.xlabel('Combined Region')
plt.ylabel('User Count')

# 연령별 userCount 그래프
plt.subplot(2, 3, 2)
sns.barplot(data=data, x='ageGroup', y='userCount')
plt.title('User Count by Age Group')
plt.xticks(rotation=45)
plt.xlabel('Age Group')
plt.ylabel('User Count')

# 시장 유형별 userCount 그래프
plt.subplot(2, 3, 3)
sns.barplot(data=data, x='marketType', y='userCount')
plt.title('User Count by Market Type')
plt.xticks(rotation=45)
plt.xlabel('Market Type')
plt.ylabel('User Count')

# 성별 userCount 그래프
plt.subplot(2, 3, 4)
sns.barplot(data=data, x='gender', y='userCount')
plt.title('User Count by Gender')
plt.xlabel('Gender')
plt.ylabel('User Count')

# 월별 userCount 그래프
plt.subplot(2, 3, 5)
sns.barplot(data=data, x='dtYearMonth', y='userCount')
plt.title('User Count by dtYearMonth')
plt.xlabel('dtYearMonth')
plt.ylabel('User Count')

# 모든 그래프 표시
plt.tight_layout()
plt.show()

# %%
# 그래프 그리기를 위한 서브플롯 설정
plt.figure(figsize=(18, 12))
plt.subplots_adjust(hspace=0.4)

# 지역별 userCount 그래프
plt.subplot(2, 3, 1)
sns.barplot(data=data, x='combined_region', y='userCount')
plt.title('User Count by Combined Region')
plt.xticks(rotation=45)
plt.xlabel('Combined Region')
plt.ylabel('User Count')

# 연령별 userCount 그래프
plt.subplot(2, 3, 2)
sns.barplot(data=data, x='ageGroup', y='userCount')
plt.title('User Count by Age Group')
plt.xticks(rotation=45)
plt.xlabel('Age Group')
plt.ylabel('User Count')

# 시장 유형별 userCount 그래프
plt.subplot(2, 3, 3)
sns.barplot(data=data, x='marketType', y='userCount')
plt.title('User Count by Market Type')
plt.xticks(rotation=45)
plt.xlabel('Market Type')
plt.ylabel('User Count')

# 성별 userCount 그래프
plt.subplot(2, 3, 4)
sns.barplot(data=data, x='gender', y='userCount')
plt.title('User Count by Gender')
plt.xlabel('Gender')
plt.ylabel('User Count')

# 월별 userCount 그래프
plt.subplot(2, 3, 5)
sns.barplot(data=data, x='dtYearMonth', y='userCount')
plt.title('User Count by dtYearMonth')
plt.xlabel('dtYearMonth')
plt.ylabel('User Count')

# 모든 그래프 표시
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# /Users/user/Visit_Jeju_BigData_Project/파일정리/카드소비패턴.ipynb Cell 13 line 7
#
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> # 지역별 userCount 그래프
#
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> plt.subplot(2, 3, 1)
#
# ----> <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> sns.barplot(data=data, x='combined_region', y='userCount')
#
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> plt.title('User Count by Combined Region')
#
#       <a href='vscode-notebook-cell:/Users/user/Visit_Jeju_BigData_Project/%ED%8C%8C%EC%9D%BC%EC%A0%95%EB%A6%AC/%EC%B9%B4%EB%93%9C%EC%86%8C%EB%B9%84%ED%8C%A8%ED%84%B4.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a> plt.xticks(rotation=45)
#
#
#
# NameError: name 'sns' is not defined
